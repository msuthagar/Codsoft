# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
df=pd.read_csv("creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321  \
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  \
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
plt.figure()
sns.countplot(data=df,y="Class")
plt.show()

# %%
for col in df:
    plt.figure()
    sns.distplot(df[col]) #distplot means distribution plot
    plt.show()

# %%
from scipy.stats import skew #for using mathmatical function skew

# %%
 skew(df["Class"])
# Out:
# 23.99745292182408

# %%
for col in df:
    print(col,":",skew(df[col]))
# Out:
# Time : -0.03556743068120296
# V1 : -3.280650024359956
# V2 : -4.624841215356954
# V3 : -2.2401436419416543
# V4 : 0.6762885361363855
# V5 : -2.425888719378559
# V6 : 1.8265710448869008
# V7 : 2.5538939666831117
# V8 : -8.521899311980174
# V9 : 0.5546768505565418
# V10 : 1.1871343376109695
# V11 : 0.35650397786795557
# V12 : -2.278388935683072
# V13 : 0.0652331143394307
# V14 : -1.9951653322115102
# V15 : -0.3084213577546761
# V16 : -1.1009604775565411
# V17 : -3.844894223735797
# V18 : -0.2598788993745328
# V19 : 0.109191184897714
# V20 : -2.0371445699300117
# V21 : 3.5929722697554753
# V22 : -0.21325649967250146
# V23 : -5.875109397316075
# V24 : -0.5524963913014509
# V25 : -0.41579040044741566
# V26 : 0.5766895799228516
# V27 : -1.170202779255609
# V28 : 11.19203224646587
# Amount : 16.97763503663315
# Class : 23.99745292182408

# %%
corr = df.corr()
plt.figure(figsize=(30,40))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
X=df.drop("Class",axis=1)

# %%
Y=df["Class"]

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321  \
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21
# ...

# %%
Y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
#Trian_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
from imblearn.over_sampling import RandomOverSampler#To n ML

# %%
rs=RandomOverSampler(random_state=1)

# %%
X_sample,Y_sample=rs.fit_resample(X_train,Y_train)

# %%
X_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6
# 191125  129124.0 -0.190075  0.203323 -0.996232 -1.596985  3.192579  3.356935  \
# 153710   99901.0 -0.000313  1.041633 -0.318849 -0.429824  0.927591 -0.784796
# 261216  159917.0  2.065603  0.071537 -1.892041  0.190985  0.681571 -0.286226
# 190724  128961.0  2.025587  0.060125 -1.843486  0.347168  0.301427 -0.955263
# 127492   78349.0 -0.482824  0.692865  1.397751  0.822699 -0.815530  0.143287
# ...          ...       ...       ...       ...       ...       ...       ...
# 21440    31666.0 -2.986845 -8.663978 -1.910863  0.664058 -3.934875  0.861269
# 117583   74729.0  0.937083 -0.849673  0.524186 -0.020031 -0.606327  0.692302
# 73349    55095.0 -1.149963  1.696462  1.637114  2.658991 -0.021502  0.192287
# 267336  162728.0  1.754554 -0.699398 -0.076332  0.443915 -0.672082  0.389061
# 128037   78576.0 -0.707635  0.493302  2.648089  1.064807 -0.680271  1.183838
#
# ...

# %%
Y_train
# Out:
# 191125    0
# 153710    0
# 261216    0
# 190724    0
# 127492    0
#          ..
# 21440     0
# 117583    0
# 73349     0
# 267336    0
# 128037    0
# Name: Class, Length: 199364, dtype: int64

# %%
Y_train.value_counts()
# Out:
# Class
# 0    199007
# 1       357
# Name: count, dtype: int64

# %%
X_sample
# Out:
#             Time         V1         V2         V3         V4         V5
# 0       129124.0  -0.190075   0.203323  -0.996232  -1.596985   3.192579  \
# 1        99901.0  -0.000313   1.041633  -0.318849  -0.429824   0.927591
# 2       159917.0   2.065603   0.071537  -1.892041   0.190985   0.681571
# 3       128961.0   2.025587   0.060125  -1.843486   0.347168   0.301427
# 4        78349.0  -0.482824   0.692865   1.397751   0.822699  -0.815530
# ...          ...        ...        ...        ...        ...        ...
# 398009  133731.0   1.176633   3.141918  -6.140445   5.521821   1.768515
# 398010   41138.0  -4.595617   5.083690  -7.581015   7.546033  -6.949165
# 398011   97235.0 -17.537592  12.352519 -20.134613  11.122771 -14.571080
# 398012   25231.0 -16.598665  10.541751 -19.818982   6.017295 -13.025901
# 398013   41743.0  -2.144411   1.073499  -2.773663   1.384394  -4.015477
#
#               V6         V7         V8        V9  ...       V20       V21
# ...

# %%
Y_sample
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 398009    1
# 398010    1
# 398011    1
# 398012    1
# 398013    1
# Name: Class, Length: 398014, dtype: int64

# %%
Y_sample.value_counts()
# Out:
# Class
# 0    199007
# 1    199007
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=70,max_depth=15)

# %%
rf.fit(X_sample,Y_sample)
# Out:
# RandomForestClassifier(max_depth=15, n_estimators=70)

# %%
y_predn=rf.predict(X_test)

# %%
print(classification_report(Y_test,y_predn))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85308
#            1       0.83      0.79      0.81       135
#
#     accuracy                           1.00     85443
#    macro avg       0.91      0.90      0.91     85443
# weighted avg       1.00      1.00      1.00     85443
